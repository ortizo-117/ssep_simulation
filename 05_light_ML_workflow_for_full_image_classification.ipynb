# %% [markdown]
# #  Light ML workflow for 5 way classification
# In this notebook we will go through a light ML workflow for image classification using the simulated data that we generated in the previous notebooks. Wew generated images based on a tibial somatosensory stimulation paradigm. We have the ERP image (time domain feautres), as well as the time frequency plots (ITPC). The overarching goal is twofold:
#
# 1) To test whether ERP or ITPC or a combination of both can be used to classify weather the stimulation response is "normal", "abnormal", or "abolished".
# 2)  To compare the performance of different models (pre-trained vs. simple CNN) on this classification task.
#
# The ultimate goal is to determine which model and which type of features (ERP vs. ITPC) can best classify the stimulation response, which can have implications for understanding the underlying neural mechanisms and for developing potential clinical applications.

# %%
# Import necessary libraries
import os
import math
import random
from typing import Dict, Tuple

import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

import torchvision
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torchvision import models
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torchvision import transforms, models
from PIL import Image

from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix

import matplotlib.pyplot as plt

# reproducibilty settings
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device


## chatgpt suggested code for deterministic behaviour
def seed_everything(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(42)
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File <frozen importlib._bootstrap_external>:1516, in _path_importer_cache(cls, path)
#
# KeyError: 'C:\\Users\\ortizo\\IdeaProjects\\ssep_simulation\\.venv\\Lib\\site-packages\\pandas\\core\\groupby'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 24
#      21 from torchvision import transforms, models
#      22 from PIL import Image
# ---> 24 from sklearn.model_selection import GroupShuffleSplit
#      25 from sklearn.metrics import classification_report, confusion_matrix
#      27 import matplotlib.pyplot as plt
#
# File ~\IdeaProjects\ssep_simulation\.venv\Lib\site-packages\sklearn\__init__.py:70
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)     67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from sklearn import __check_build, _distributor_init  # noqa: E402 F401
# ---> 70 from sklearn.base import clone  # noqa: E402
#      71 from sklearn.utils._show_versions import show_versions  # noqa: E402
#      73 _submodules = [
#      74     "calibration",
#      75     "cluster",
#    (...)    111     "compose",
#     112 ]
#
# File ~\IdeaProjects\ssep_simulation\.venv\Lib\site-packages\sklearn\base.py:19
#      17 from sklearn._config import config_context, get_config
#      18 from sklearn.exceptions import InconsistentVersionWarning
# ---> 19 from sklearn.utils._metadata_requests import _MetadataRequester, _routing_enabled
#      20 from sklearn.utils._missing import is_pandas_na, is_scalar_nan
#      21 from sklearn.utils._param_validation import validate_parameter_constraints
#
# File ~\IdeaProjects\ssep_simulation\.venv\Lib\site-packages\sklearn\utils\__init__.py:9
#       7 from sklearn.utils import metadata_routing
#       8 from sklearn.utils._bunch import Bunch
# ----> 9 from sklearn.utils._chunking import gen_batches, gen_even_slices
#      11 # Make _safe_indexing importable from here for backward compat as this particular
#      12 # helper is considered semi-private and typically very useful for third-party
#      13 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      14 # _safe_indexing was included in our public API documentation despite the leading
#      15 # `_` in its name.
#      16 from sklearn.utils._indexing import _safe_indexing, resample, shuffle
#
# File ~\IdeaProjects\ssep_simulation\.venv\Lib\site-packages\sklearn\utils\_chunking.py:11
#       8 import numpy as np
#      10 from sklearn._config import get_config
# ---> 11 from sklearn.utils._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File ~\IdeaProjects\ssep_simulation\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:17
#      14 from scipy.sparse import csr_matrix, issparse
#      16 from sklearn._config import config_context, get_config
# ---> 17 from sklearn.utils.validation import _is_arraylike_not_scalar
#      20 class InvalidParameterError(ValueError, TypeError):
#      21     """Custom exception to be raised when the parameter of a class/method/function
#      22     does not have a valid type or value.
#      23     """
#
# File ~\IdeaProjects\ssep_simulation\.venv\Lib\site-packages\sklearn\utils\validation.py:24
#      18 from sklearn import get_config as _get_config
#      19 from sklearn.exceptions import (
#      20     DataConversionWarning,
#      21     NotFittedError,
#      22     PositiveSpectrumWarning,
#      23 )
# ---> 24 from sklearn.utils._array_api import (
#      25     _asarray_with_order,
#      26     _convert_to_numpy,
#      27     _is_numpy_namespace,
#      28     _max_precision_float_dtype,
#      29     get_namespace,
#      30     get_namespace_and_device,
#      31 )
#      32 from sklearn.utils._dataframe import is_pandas_df, is_pandas_df_or_series
#      33 from sklearn.utils._isfinite import FiniteStatus, cy_isfinite
#
# File ~\IdeaProjects\ssep_simulation\.venv\Lib\site-packages\sklearn\utils\_array_api.py:20
#      18 from sklearn.externals.array_api_compat import numpy as np_compat
#      19 from sklearn.utils._dataframe import is_df_or_series
# ---> 20 from sklearn.utils.fixes import parse_version
#      22 # TODO: complete __all__
#      23 __all__ = ["xpx"]  # we import xpx here just to re-export it, need this to appease ruff
#
# File ~\IdeaProjects\ssep_simulation\.venv\Lib\site-packages\sklearn\utils\fixes.py:19
#      16 import scipy.stats
#      18 try:
# ---> 19     import pandas as pd
#      20 except ImportError:
#      21     pd = None
#
# File ~\IdeaProjects\ssep_simulation\.venv\Lib\site-packages\pandas\__init__.py:58
#      55 # let init-time option registration happen
#      56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#      61     Int8Dtype,
#      62     Int16Dtype,
#      63     Int32Dtype,
#      64     Int64Dtype,
#      65     UInt8Dtype,
#      66     UInt16Dtype,
#      67     UInt32Dtype,
#      68     UInt64Dtype,
#      69     Float32Dtype,
#      70     Float64Dtype,
#      71     CategoricalDtype,
#      72     PeriodDtype,
#      73     IntervalDtype,
#      74     DatetimeTZDtype,
#      75     StringDtype,
#      76     BooleanDtype,
#      77     # missing
#      78     NA,
#      79     isna,
#      80     isnull,
#      81     notna,
#      82     notnull,
#      83     # indexes
#      84     Index,
#      85     CategoricalIndex,
#      86     RangeIndex,
#      87     MultiIndex,
#      88     IntervalIndex,
#      89     TimedeltaIndex,
#      90     DatetimeIndex,
#      91     PeriodIndex,
#      92     IndexSlice,
#      93     # tseries
#      94     NaT,
#      95     Period,
#      96     period_range,
#      97     Timedelta,
#      98     timedelta_range,
#      99     Timestamp,
#     100     date_range,
#     101     bdate_range,
#     102     Interval,
#     103     interval_range,
#     104     DateOffset,
#     105     # conversion
#     106     to_numeric,
#     107     to_datetime,
#     108     to_timedelta,
#     109     # misc
#     110     Flags,
#     111     Grouper,
#     112     factorize,
#     113     unique,
#     114     NamedAgg,
#     115     array,
#     116     Categorical,
#     117     set_eng_float_format,
#     118     Series,
#     119     DataFrame,
#     120 )
#     121 from pandas.core.col import col
#     123 from pandas.core.dtypes.dtypes import SparseDtype
#
# File ~\IdeaProjects\ssep_simulation\.venv\Lib\site-packages\pandas\core\api.py:46
#      44 from pandas.core.construction import array  # noqa: ICN001
#      45 from pandas.core.flags import Flags
# ---> 46 from pandas.core.groupby import (
#      47     Grouper,
#      48     NamedAgg,
#      49 )
#      50 from pandas.core.indexes.api import (
#      51     CategoricalIndex,
#      52     DatetimeIndex,
#    (...)     58     TimedeltaIndex,
#      59 )
#      60 from pandas.core.indexes.datetimes import (
#      61     bdate_range,
#      62     date_range,
#      63 )
#
# File ~\IdeaProjects\ssep_simulation\.venv\Lib\site-packages\pandas\core\groupby\__init__.py:1
# ----> 1 from pandas.core.groupby.generic import (
#       2     DataFrameGroupBy,
#       3     NamedAgg,
#       4     SeriesGroupBy,
#       5 )
#       6 from pandas.core.groupby.groupby import GroupBy
#       7 from pandas.core.groupby.grouper import Grouper
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1322, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:1262, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1559, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1531, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1518, in _path_importer_cache(cls, path)
#
# File <frozen importlib._bootstrap_external>:1494, in _path_hooks(path)
#
# File <frozen zipimport>:79, in __init__(self, path)
#
# File <frozen importlib._bootstrap_external>:152, in _path_stat(path)
#
# KeyboardInterrupt:

# %% [markdown]
# # Handling labels and metadata
# Here we will turn the condition column in our mapping.csv file into the 3 target classes.

# %%
import pandas as pd
from pathlib import Path
import re

df = pd.read_csv("anonimized_simulated_data/mapping.csv")  # or "/mnt/data/mapping.csv" in your environment

# 1) Map conditions -> 3-class labels
def map_condition_to_label(cond: str) -> str:
    c = str(cond).lower().strip()
    # normalize some possible spellings
    c = c.replace("reduced_delayed", "reduced_delayed_combined")  # replace any variant of "reduced_delayed" with a consistent name "reduced_delayed_combined"

    if c == "normal_sub":
        return "normal"
    if c == "abolished_sub":
        return "abolished"
    if c in {"delayed_sub"}:
        return "delayed"
    if c in {"reduced_sub"}:
            return "reduced"
    if c in {"reduced_and_delayed"}:
        return "reduced_and_delayed"


    # If something unexpected appears, force you to notice
    raise ValueError(f"Unknown condition: {cond}")

df["label"] = df["condition"].apply(map_condition_to_label)

# 2) Build file paths (set these to your actual folders)
ERP_DIR  = Path("anonimized_simulated_data/erp_image")   # <-- change
ITPC_DIR = Path("anonimized_simulated_data/itpc_image")  # <-- change
FULL_DIR = Path("anonimized_simulated_data/full_report") # <-- change
df["erp_path"]  = df["anonimized_file_name_erp"].apply(lambda x: str(ERP_DIR / x))
df["itpc_path"] = df["anonimized_file_name_itpc"].apply(lambda x: str(ITPC_DIR / x))
df["full_path"] = df["anonimized_file_name_full_report"].apply(lambda x: str(FULL_DIR / x))

# 3) subject_id: extract the anonymized subject number from filenames like "subject_7279_erp.jpg"
def extract_subject_id(fname: str) -> str:
    m = re.search(r"(subject_\d+)", str(fname).lower())
    return m.group(1) if m else str(fname)

df["subject_id"] = df["anonimized_file_name_erp"].apply(extract_subject_id)

# 4) sample_id: unique per row
df["sample_id"] = df.index.astype(str)

# 5) Final metadata (what your ML pipeline wants)
meta = df[["sample_id", "subject_id", "label", "erp_path", "itpc_path","full_path"]].copy()

# Optional: integer targets
class_names = sorted(meta["label"].unique())  # e.g. ["abnormal", "normal", "reduced"]
label_to_idx = {c:i for i,c in enumerate(class_names)} # this will be used for the model output layer and loss function. make sure the order matches the class names in the classification report later.
meta["y"] = meta["label"].map(label_to_idx)

# print y and class mappings to check
print("Class to index mapping:", label_to_idx)
# See class counts after merging delayed/reduced into abnormal
meta["label"].value_counts()
# should show something like:
# abnormal      300
# normal        300
# abolished     300
# Out:
# Class to index mapping: {'abolished': 0, 'delayed': 1, 'normal': 2, 'reduced': 3, 'reduced_and_delayed': 4}
# label
# abolished              300
# normal                 300
# delayed                100
# reduced_and_delayed    100
# reduced                100
# Name: count, dtype: int64

# %% [markdown]
# Now we do train/val/ test splotting by group.

# %%
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42) # we use GroupShuffleSplit to ensure that all samples from the same subject_id end up in the same split (train, val, or test).
train_idx, test_idx = next(gss.split(meta, groups=meta["subject_id"]))
train_df = meta.iloc[train_idx].reset_index(drop=True)
test_df = meta.iloc[test_idx].reset_index(drop=True)

gss2 = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx2, val_idx = next(gss2.split(train_df, groups=train_df["subject_id"]))
train_df2  = train_df.iloc[train_idx2].reset_index(drop=True)
val_df = train_df.iloc[val_idx].reset_index(drop=True)
train_df = train_df2

# check splits
print("Train label distribution:\n", train_df["label"].value_counts())
print("Train y distribution:\n", train_df["y"].value_counts())
print("\nVal label distribution:\n", val_df["label"].value_counts())
print("\nTest label distribution:\n", test_df["label"].value_counts())

# add numbers to check that there are no overlaps in subject_id between splits
print("\nUnique subject_ids in train:", train_df["subject_id"].nunique())
print("Unique subject_ids in val:", val_df["subject_id"].nunique())
print("Unique subject_ids in test:", test_df["subject_id"].nunique())
print("\nTotal unique subject_ids:", meta["subject_id"].nunique())
# Out:
# Train label distribution:
#  label
# abolished              197
# normal                 183
# reduced                 66
# delayed                 65
# reduced_and_delayed     65
# Name: count, dtype: int64
# Train y distribution:
#  y
# 0    197
# 2    183
# 3     66
# 1     65
# 4     65
# Name: count, dtype: int64
#
# Val label distribution:
#  label
# abolished              47
# normal                 45
# reduced                23
# delayed                15
# reduced_and_delayed    14
# Name: count, dtype: int64
#
# Test label distribution:
#  label
# normal                 72
# abolished              56
# reduced_and_delayed    21
# delayed                20
# reduced                11
# Name: count, dtype: int64
#
# Unique subject_ids in train: 576
# Unique subject_ids in val: 144
# Unique subject_ids in test: 180
#
# Total unique subject_ids: 900

# %% [markdown]
# # Images into tensors
# We already made sure our inputs are constant sizes, and removed labels/axis from them  when we generated them but we might want to transform them into consistent formats to match the inputs of the models being used. For example, if we use a pre-trained ResNet, it expects 3-channel RGB images of size 224x224. If our ERP and ITPC images are grayscale and of different sizes, we will need to convert them to the expected format. We can do this using torchvision transforms. We will create a custom dataset class that loads the images, applies the necessary transformations. First we look at some examples of inputs.

# %%
# determine image sizes and channels
from PIL import Image
def get_image_info(path: str) -> Tuple[int, int, int]:
    with Image.open(path) as img:
        return img.size[0], img.size[1], len(img.getbands())
# check a few images
print(get_image_info(train_df["erp_path"].iloc[0]))  # e.g. (300, 200, 1) for a grayscale image of size 300x200
print(get_image_info(train_df["itpc_path"].iloc[0])) # e.g. (300, 200, 1) for a grayscale image of size 300x200

# display an example ERP image
img = Image.open(train_df["erp_path"].iloc[0])
plt.imshow(img, cmap="gray")
plt.title(f"Label: {train_df['label'].iloc[0]}")
plt.axis("off")
plt.show()

# display an example ITPC image
img = Image.open(train_df["itpc_path"].iloc[0])
plt.imshow(img, cmap="gray")
plt.title(f"Label: {train_df['label'].iloc[0]}")
plt.axis("off")
plt.show()
# Out:
# (3000, 1000, 3)
# (2000, 2000, 3)

# %%
# Here we will define the transforms to get the data into the models. for now lets assume an IMG_SIZE of 224. Depending on the model I might need to change this. If looking at the ERP, we can convert to grayscale and test inputs as 1-channels. For ITPC, we keep them as a 3-channel RGB (model dependent). If we want to use both ERP and ITPC together, we will need to make sure they have the same number of channels and the same size. For simplicity, we can convert both to 3-channel RGB and resize them to 224x224. This way we can easily feed them into a pre-trained ResNet or a simple CNN.

IMG_SIZE = 224
# train transform for ERP and ITPC (both converted to 3-channel RGB and resized to 224x224)
train_tfms = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),  # resize to expected size
    #transforms.RandomCrop((IMG_SIZE, IMG_SIZE), padding=4, padding_mode="edge"), # very light augmentation. might try not doing any but for now this is ok. propably will do a testing grid later with different augmentations. For now because of the very deterministic generation of images, we are not doing any.
    #transforms.ColorJitter(brightness=0.08, contrast=0.08, saturation=0.02, hue=0.0),
    #transforms.Grayscale(num_output_channels=3),  # convert to 3-channel grayscale (if needed)
    transforms.ToTensor(),  # convert to tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])  # normalize to [-1, 1]. actually changed to ImageNet stats since we are using pretained models.
])

# eval and test transforms (same as train but without data augmentation)
eval_tfms = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),# convert to tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# # Dataset class defiinition
# Now we will define a custom dataset class that can load the ERP and ITPC images and both images.

# %%
def load_image(path):
    return Image.open(path).convert("RGB")

class StimDataset(Dataset):
    def __init__(self, df, mode="erp", transform=None):
        """
        mode: 'erp', 'itpc', 'both'
        """
        self.df = df.reset_index(drop=True)
        self.mode = mode
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        y = int(row["y"])

        if self.mode == "erp":
            img = load_image(row["erp_path"])
            x = self.transform(img) if self.transform else img
            return x, y

        if self.mode == "itpc":
            img = load_image(row["itpc_path"])
            x = self.transform(img) if self.transform else img
            return x, y

        if self.mode == "both":
            img1 = load_image(row["erp_path"])
            img2 = load_image(row["itpc_path"])
            x1 = self.transform(img1) if self.transform else img1
            x2 = self.transform(img2) if self.transform else img2
            return (x1, x2), y

        raise ValueError("mode must be one of: 'erp', 'itpc', 'both'")

# testing the dataset
ex_id = 100
example_row = train_df.iloc[ex_id]
print("Example row:\n", example_row)
dataset_erp = StimDataset(train_df, mode="erp", transform=train_tfms)
dataset_itpc = StimDataset(train_df, mode="itpc", transform=train_tfms)
dataset_both = StimDataset(train_df, mode="both", transform=train_tfms)
x_erp, y_erp = dataset_erp[ex_id]
x_itpc, y_itpc = dataset_itpc[ex_id]
(x_both_erp, x_both_itpc), y_both = dataset_both[ex_id]
print("\nERP image tensor shape:", x_erp.shape)  # should be (3, 224, 224)
print("ITPC image tensor shape:", x_itpc.shape)  # should be (3, 224, 224)
print("Both ERP and ITPC image tensor shapes:", x_both_erp.shape, x_both_itpc.shape)  # should both be (3, 224, 224)
print("Label:", y_erp, y_itpc, y_both)  # should all be the same

# display the images from the dataset to check transforms
def show_image(tensor_img, title=""):
    img = tensor_img.permute(1, 2, 0).numpy()
    img = (img * 0.5) + 0.5  # unnormalize
    plt.imshow(img)
    plt.title(title)
    plt.axis("off")

plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
show_image(x_erp, title=f"ERP - Label: {y_erp}")
plt.subplot(1, 3, 2)
show_image(x_itpc, title=f"ITPC - Label: {y_itpc}")
plt.subplot(1, 3, 3)
show_image(x_both_itpc, title=f"Both ERP - Label: {y_both}")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.31064308..1.82].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.82].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.82].
# Example row:
#  sample_id                                                   151
# subject_id                                         subject_1352
# label                                                 abolished
# erp_path      anonimized_simulated_data\erp_image\subject_13...
# itpc_path     anonimized_simulated_data\itpc_image\subject_1...
# full_path     anonimized_simulated_data\full_report\subject_...
# y                                                             0
# Name: 100, dtype: object
#
# ERP image tensor shape: torch.Size([3, 224, 224])
# ITPC image tensor shape: torch.Size([3, 224, 224])
# Both ERP and ITPC image tensor shapes: torch.Size([3, 224, 224]) torch.Size([3, 224, 224])
# Label: 0 0 0

# %% [markdown]
# # Class imbalance handling
# Before we start training, we should check if there is any class imbalance in our dataset. If there are, we can deal with them witht eh WeightedRandomSampler in the DataLoader. This will ensure that during training, the model sees a balanced number of samples from each class, which can help improve performance on minority classes.

# %%
counts = train_df["y"].value_counts()
class_weights = (1.0 / counts)

sample_weights = torch.tensor(
    class_weights.reindex(train_df["y"]).to_numpy(),
    dtype=torch.double
)
sampler = WeightedRandomSampler(sample_weights, num_samples=len(sample_weights), replacement=True)

# check the weights
print("Class counts:\n", counts)
print("\nClass weights:\n", class_weights)
print("\nSample weights:\n", sample_weights[:10])  # print first 10

# no class imbalance in our dataset since we generated it with equal samples per class, but this is how you would handle it if there was an imbalance. We will use the sampler in the DataLoader for training.
# Out:
# Class counts:
#  y
# 0    197
# 2    183
# 3     66
# 1     65
# 4     65
# Name: count, dtype: int64
#
# Class weights:
#  y
# 0    0.005076
# 2    0.005464
# 3    0.015152
# 1    0.015385
# 4    0.015385
# Name: count, dtype: float64
#
# Sample weights:
#  tensor([0.0051, 0.0051, 0.0051, 0.0051, 0.0051, 0.0051, 0.0051, 0.0051, 0.0051,
#         0.0051], dtype=torch.float64)

# %% [markdown]
# # Dataloaders
# Here we define the dataloaders for training, validation and testing.

# %%
BATCH_SIZE = 32

def make_loaders(mode):
    train_ds = StimDataset(train_df, mode=mode, transform=train_tfms)
    val_ds   = StimDataset(val_df, mode=mode, transform=eval_tfms)
    test_ds  = StimDataset(test_df, mode=mode, transform=eval_tfms)

    train_dl = DataLoader(train_ds, batch_size=BATCH_SIZE, sampler=sampler, num_workers=0, pin_memory=False)
    val_dl   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=False)
    test_dl  = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=False)
    return train_dl, val_dl, test_dl

# %% [markdown]
# # Model definitions - simple CNN vs. Resnet18 vs. EfficientNetV2
# Here we will define the models we want to use for classification. We will start with a simpleCNN and ResNet18.

# %%
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=3):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 16, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2), # 3 input channels, 16 output channels, kernel size of 3, padding of 1.
            nn.Conv2d(16, 32, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(64, 128, 3, padding=1), nn.ReLU(), nn.AdaptiveAvgPool2d((1,1)), # adaptive avgpool.
        )
        self.classifier = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.features(x).flatten(1)
        return self.classifier(x)


def _set_bn_eval(module: nn.Module):
    for m in module.modules():
        if isinstance(m, (nn.BatchNorm2d, nn.SyncBatchNorm)):
            m.eval()

def make_resnet18(num_classes=3, freeze_backbone=True):
    m = models.resnet18(weights=models.ResNet18_Weights.DEFAULT) # load pretrained weights

    # Replace head first
    m.fc = nn.Linear(m.fc.in_features, num_classes)

    if freeze_backbone: # freezing for transfer learning
        # Freeze everything
        for p in m.parameters():
            p.requires_grad = False
        # Unfreeze head
        for p in m.fc.parameters():
            p.requires_grad = True
        # Freeze BN running stats
        _set_bn_eval(m)

    # Sanity check
    num_trainable = sum(p.numel() for p in m.parameters() if p.requires_grad)
    print(f"ResNet18 freeze_backbone={freeze_backbone} trainable params: {num_trainable:,}")
    return m



def make_effnetv2_single(num_classes=3, pretrained=True, freeze_backbone=True):
    weights = models.EfficientNet_V2_S_Weights.DEFAULT if pretrained else None
    model = models.efficientnet_v2_s(weights=weights)  # <-- correct name

    # Replace head
    in_features = model.classifier[1].in_features
    model.classifier[1] = nn.Linear(in_features, num_classes)

    if freeze_backbone:
        # Freeze all params
        for p in model.parameters():
            p.requires_grad = False
        # Unfreeze classifier params
        for p in model.classifier.parameters():
            p.requires_grad = True

        # Optional: freeze BN running stats (EffNet has BN too)
        for m in model.modules():
            if isinstance(m, (nn.BatchNorm2d, nn.SyncBatchNorm)):
                m.eval()

    return model

# helper to see the trainable params
def count_trainable(m):
    total = sum(p.numel() for p in m.parameters())
    trainable = sum(p.numel() for p in m.parameters() if p.requires_grad)
    print(f"Trainable: {trainable:,} / Total: {total:,}")

# %% [markdown]
# # Two input late fusion models
# Here we will define a simple late fusion CNN and a late fusion resnet18. For the simple one, since we are training them, I defined each branch separately so that they do not share the same weights. These will allow for combining both ERP and ITPC features for classification. The late fusion approach means that we will process the ERP and ITPC images separately through their own feature extractors, and then combine the extracted features before the final classification layer.

# %%
from torchvision.models import efficientnet_v2_s, EfficientNet_V2_S_Weights

class SimpleFusionCNN(nn.Module):
    def __init__(self, num_classes=3):
        super().__init__()
        self.erp_branch = SimpleCNN(num_classes=128)
        self.itpc_branch = SimpleCNN(num_classes=128)

        self.erp_branch.classifier = nn.Identity()
        self.itpc_branch.classifier = nn.Identity()

        self.fc = nn.Linear(128 + 128, num_classes)

    def forward(self, x_erp, x_itpc):
        e1 = self.erp_branch(x_erp)   # (B,128)
        e2 = self.itpc_branch(x_itpc) # (B,128)
        z = torch.cat([e1, e2], dim=1)
        return self.fc(z)





class ResNetFusion(nn.Module):
    def __init__(self, num_classes=3, freeze_backbone=True):
        super().__init__()
        self.erp = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
        self.itpc = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)

        # remove final classifier, keep embedding
        erp_dim = self.erp.fc.in_features
        itpc_dim = self.itpc.fc.in_features
        self.erp.fc = nn.Identity()
        self.itpc.fc = nn.Identity()

        self.head = nn.Sequential(
            nn.Linear(erp_dim + itpc_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, num_classes)
        )

        if freeze_backbone:
            for p in self.erp.parameters():
                p.requires_grad = False
            for p in self.itpc.parameters():
                p.requires_grad = False

            # keep BN running stats fixed when backbone is frozen
            self._set_bn_eval(self.erp)
            self._set_bn_eval(self.itpc)

            # make sure head is trainable
            for p in self.head.parameters():
                p.requires_grad = True

    def forward(self, x1, x2):
        e1 = self.erp(x1)
        e2 = self.itpc(x2)
        return self.head(torch.cat([e1, e2], dim=1))

    @staticmethod
    def _set_bn_eval(module: nn.Module):
        for m in module.modules():
            if isinstance(m, (nn.BatchNorm2d, nn.SyncBatchNorm)):
                m.eval()




class EffNetV2LateFusionTwoTowers(nn.Module):
    def __init__(
            self,
            num_classes: int = 3,
            pretrained: bool = True,
            hidden: int = 512, # size of the hidden layer in the fusion head
            freeze_backbone: bool = True,
            freeze_bn_stats: bool = True,  # recommended when freezing backbone
    ):
        super().__init__()
        weights = EfficientNet_V2_S_Weights.DEFAULT if pretrained else None

        erp_net = efficientnet_v2_s(weights=weights)
        itpc_net = efficientnet_v2_s(weights=weights)

        self.erp_features = erp_net.features # feature extractor part of the network (everything except the classifier)
        self.itpc_features = itpc_net.features
        self.erp_pool = erp_net.avgpool # pooling layer. average pooling.
        self.itpc_pool = itpc_net.avgpool

        feat_dim = erp_net.classifier[1].in_features  # should be 1280 for effnetv2_s

        self.fusion_head = nn.Sequential(
            nn.Linear(feat_dim * 2, hidden),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.2),
            nn.Linear(hidden, num_classes),
        )

        if freeze_backbone:
            for p in self.erp_features.parameters():
                p.requires_grad = False
            for p in self.itpc_features.parameters():
                p.requires_grad = False

            # If you're freezing, also freezing BN running stats is often safer
            if freeze_bn_stats:
                self._set_bn_eval(self.erp_features)
                self._set_bn_eval(self.itpc_features)

        # explicitly make sure head is trainable
        for p in self.fusion_head.parameters():
            p.requires_grad = True

    @staticmethod
    def _set_bn_eval(module: nn.Module):
        for m in module.modules():
            if isinstance(m, (nn.BatchNorm2d, nn.SyncBatchNorm)):
                m.eval()

    def encode_erp(self, x: torch.Tensor) -> torch.Tensor:
        x = self.erp_features(x)
        x = self.erp_pool(x)
        return torch.flatten(x, 1)

    def encode_itpc(self, x: torch.Tensor) -> torch.Tensor:
        x = self.itpc_features(x)
        x = self.itpc_pool(x)
        return torch.flatten(x, 1)

    def forward(self, erp: torch.Tensor, itpc: torch.Tensor) -> torch.Tensor:
        f_erp = self.encode_erp(erp)
        f_itpc = self.encode_itpc(itpc)
        fused = torch.cat([f_erp, f_itpc], dim=1)
        return self.fusion_head(fused)

# %% [markdown]
# # Defining the training loop
# Here we have an adaptable training loop (works for single and dual input models) tha takes the model, the dataloader, and the optimizers and trains the model for one epoch. We will also define a function for evaluating the model on the validation and test sets.

# %%
import torch.nn.functional as F


def run_epoch(model, dl, device, optimizer=None, grad_clip=None):
    train = optimizer is not None
    print(f"{'Training' if train else 'Evaluating'} for one epoch...")

    model.train() if train else model.eval()

    total_loss, correct, total = 0.0, 0, 0
    all_preds, all_y = [], []

    for bi, batch in enumerate(dl, start=1):
        print(f"Processing batch {bi}/{len(dl)}...")

        # ---- unpack batch robustly ----
        x1 = x2 = None

        if isinstance(batch, (list, tuple)):
            if len(batch) == 2:
                x, y = batch
                # case: ((x1, x2), y)
                if isinstance(x, (list, tuple)) and len(x) == 2:
                    x1, x2 = x
                # case: ({"itpc":..., "erp":...}, y)
                elif isinstance(x, dict) and "itpc" in x and "erp" in x:
                    x1, x2 = x["itpc"], x["erp"]
                else:
                    # case: (x, y) single input
                    x_single = x
            elif len(batch) == 3:
                # case: (x1, x2, y)
                x1, x2, y = batch
            else:
                raise ValueError(f"Unexpected batch length: {len(batch)}")
        else:
            raise ValueError(f"Unexpected batch type: {type(batch)}")

        # ---- forward/loss (no grad in eval) ----
        with torch.set_grad_enabled(train):
            y = y.to(device)

            if x1 is not None and x2 is not None:
                x1 = x1.to(device)
                x2 = x2.to(device)
                logits = model(x1, x2)
            else:
                x_single = x_single.to(device)
                logits = model(x_single)

            loss = F.cross_entropy(logits, y)

            if train:
                optimizer.zero_grad(set_to_none=True)
                loss.backward()
                if grad_clip is not None:
                    torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)
                optimizer.step()

        # ---- metrics ----
        bs = y.size(0)
        total_loss += loss.item() * bs
        preds = logits.argmax(dim=1)
        correct += (preds == y).sum().item()
        total += bs

        all_preds.append(preds.detach().cpu().numpy())
        all_y.append(y.detach().cpu().numpy())

    avg_loss = total_loss / max(total, 1)
    acc = correct / max(total, 1)

    all_preds = np.concatenate(all_preds) if all_preds else np.array([])
    all_y = np.concatenate(all_y) if all_y else np.array([])

    print(f"{'Train' if train else 'Eval'} - Loss: {avg_loss:.4f}, Acc: {acc:.3f}")
    return avg_loss, acc, all_y, all_preds

# %% [markdown]
# # Fit with early stopping
# Now we will define a function to fit the model for multiple epochs, with early stopping based on validation loss. We will also keep track of the best model based on validation performance.

# %%
def fit(model, train_dl, val_dl, lr=1e-3, epochs=15, patience=3):
    model.to(device)

    # Only optimize trainable params
    params = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.Adam(params, lr=lr)

    best_val = float("inf")
    best_state = None
    bad = 0

    hist = []
    for ep in range(1, epochs+1):
        print(f"Epoch {ep}/{epochs} starting...")
        tr_loss, tr_acc, _, _ = run_epoch(model, train_dl, device=device, optimizer=optimizer)
        va_loss, va_acc, _, _ = run_epoch(model, val_dl, device=device, optimizer=None)

        hist.append({"epoch": ep, "tr_loss": tr_loss, "tr_acc": tr_acc,
                     "va_loss": va_loss, "va_acc": va_acc})

        print(f"Epoch {ep:02d} | train loss {tr_loss:.4f} acc {tr_acc:.3f} | val loss {va_loss:.4f} acc {va_acc:.3f}")

        if va_loss < best_val - 1e-4:
            best_val = va_loss
            best_state = {k:v.cpu().clone() for k,v in model.state_dict().items()}
            bad = 0
        else:
            bad += 1
            if bad >= patience:
                print("Early stopping.")
                break

    if best_state:
        model.load_state_dict(best_state)
    return pd.DataFrame(hist), model

# %% [markdown]
# # Test eval and confusion matrix
# Finally, we will define a function to evaluate the best model on the test set and compute the classification report and confusion matrix.

# %%
def evaluate(model, test_dl, class_names):
    loss, acc, y_true, y_pred = run_epoch(model, test_dl, device=device, optimizer=None)
    print(f"Test loss: {loss:.4f} | Test acc: {acc:.3f}\n")

    print(classification_report(y_true, y_pred, target_names=class_names))

    # confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(5,5))
    im = plt.imshow(cm, cmap="magma", vmin=0)  # <- unidirectional cmap
    plt.title("Confusion Matrix for " + model.__class__.__name__)
    plt.xticks(range(len(class_names)), class_names, rotation=45)
    plt.yticks(range(len(class_names)), class_names)

    plt.colorbar(im, fraction=0.046, pad=0.04)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.tight_layout()
    plt.show()

    return {"loss": loss, "acc": acc, "cm": cm}

# %% [markdown]
# # EXPERIMENTS! HOW EXCITING!
# Now we can run our experiments by training the different models (SimpleCNN, ResNet18, SimpleFusionCNN, ResNetFusion) on the different input types (ERP, ITPC, Both) and evaluating their performance on the test set. We can then compare the results to see which model and which input type performs best for classifying the stimulation response. We can also analyze the confusion matrices to see if there are specific classes that are more often confused with each other. This will give us insights into which features (ERP vs. ITPC) are more informative for the classification task and how well the models are able to learn from those features.
#
# First let us define an experiment runner

# %%
def run_experiment(mode, model_kind):
    train_dl, val_dl, test_dl = make_loaders(mode)

    if mode in ["erp", "itpc"]:
        if model_kind == "simple":
            model = SimpleCNN(num_classes=5)
        elif model_kind == "resnet":
            model = make_resnet18(num_classes=5, freeze_backbone=True)
        elif model_kind == "effnet":
            model = make_effnetv2_single(num_classes=5, freeze_backbone=True)
        else:
            raise ValueError("model_kind must be 'simple' or 'pretrained'")

    elif mode == "both":
        if model_kind == "simple":
            model = SimpleFusionCNN(num_classes=5)
        elif model_kind == "resnet":
            model = ResNetFusion(num_classes=5, freeze_backbone=True)
        elif model_kind == "effnet":
            model = EffNetV2LateFusionTwoTowers(num_classes=5, freeze_backbone=True)
        else:
            raise ValueError("model_kind must be 'simple' or 'pretrained'")
    else:
        raise ValueError("mode must be 'erp', 'itpc', 'both'")

    print(f"Running experiment with mode={mode} and model_kind={model_kind}...")
    print(f"Number of trainable parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}")
    print("Starting training...")
    hist, model = fit(model, train_dl, val_dl, lr=1e-3, epochs=20, patience=6)
    print("Training completed. Evaluating on test set...")
    metrics = evaluate(model, test_dl, class_names)
    print(f" Evaluation done. Test set results:\n{metrics}")

    out = {
        "mode": mode,
        "model": model_kind,
        "test_acc": metrics["acc"],
        "test_loss": metrics["loss"],
    }
    return out, hist

# %% [markdown]
# # Experiment grid
# We will take erp, itpc, and both as input modes, and simple vs. pretrained as model kinds, and run the experiments for all combinations.

# %%
results = []
hists = {}

for mode in ["erp", "itpc", "both"]:
    for mk in ["effnet","resnet","simple"]:
        print("\n" + "="*80)
        print(f"MODE={mode} | MODEL={mk}")
        out, hist = run_experiment(mode, mk)
        results.append(out)
        hists[(mode, mk)] = hist

res_df = pd.DataFrame(results).sort_values("test_acc", ascending=False)
res_df
# Out:
# ================================================================================
# MODE=erp | MODEL=effnet
# Running experiment with mode=erp and model_kind=effnet...
# Number of trainable parameters: 6405
# Starting training...
# Epoch 1/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.5552, Acc: 0.299
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.5304, Acc: 0.403
# Epoch 01 | train loss 1.5552 acc 0.299 | val loss 1.5304 acc 0.403
# Epoch 2/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.3816, Acc: 0.488
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.3139, Acc: 0.583
# Epoch 02 | train loss 1.3816 acc 0.488 | val loss 1.3139 acc 0.583
# Epoch 3/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.2769, Acc: 0.549
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.2123, Acc: 0.535
# Epoch 03 | train loss 1.2769 acc 0.549 | val loss 1.2123 acc 0.535
# Epoch 4/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.2111, Acc: 0.559
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.1585, Acc: 0.521
# Epoch 04 | train loss 1.2111 acc 0.559 | val loss 1.1585 acc 0.521
# Epoch 5/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.1241, Acc: 0.630
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.1145, Acc: 0.514
# Epoch 05 | train loss 1.1241 acc 0.630 | val loss 1.1145 acc 0.514
# Epoch 6/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.1185, Acc: 0.585
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.1218, Acc: 0.535
# Epoch 06 | train loss 1.1185 acc 0.585 | val loss 1.1218 acc 0.535
# Epoch 7/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.1017, Acc: 0.556
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.1131, Acc: 0.507
# Epoch 07 | train loss 1.1017 acc 0.556 | val loss 1.1131 acc 0.507
# Epoch 8/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.0156, Acc: 0.635
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.0455, Acc: 0.569
# Epoch 08 | train loss 1.0156 acc 0.635 | val loss 1.0455 acc 0.569
# Epoch 9/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.0791, Acc: 0.594
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.0753, Acc: 0.514
# Epoch 09 | train loss 1.0791 acc 0.594 | val loss 1.0753 acc 0.514
# Epoch 10/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.0307, Acc: 0.630
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.0750, Acc: 0.521
# Epoch 10 | train loss 1.0307 acc 0.630 | val loss 1.0750 acc 0.521
# Epoch 11/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9853, Acc: 0.620
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.9998, Acc: 0.597
# Epoch 11 | train loss 0.9853 acc 0.620 | val loss 0.9998 acc 0.597
# Epoch 12/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9828, Acc: 0.634
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.0128, Acc: 0.597
# Epoch 12 | train loss 0.9828 acc 0.634 | val loss 1.0128 acc 0.597
# Epoch 13/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.0161, Acc: 0.608
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.9980, Acc: 0.597
# Epoch 13 | train loss 1.0161 acc 0.608 | val loss 0.9980 acc 0.597
# Epoch 14/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9920, Acc: 0.632
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.0167, Acc: 0.562
# Epoch 14 | train loss 0.9920 acc 0.632 | val loss 1.0167 acc 0.562
# Epoch 15/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9727, Acc: 0.632
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.0273, Acc: 0.549
# Epoch 15 | train loss 0.9727 acc 0.632 | val loss 1.0273 acc 0.549
# Epoch 16/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9442, Acc: 0.668
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.0290, Acc: 0.535
# Epoch 16 | train loss 0.9442 acc 0.668 | val loss 1.0290 acc 0.535
# Epoch 17/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9487, Acc: 0.651
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.0245, Acc: 0.549
# Epoch 17 | train loss 0.9487 acc 0.651 | val loss 1.0245 acc 0.549
# Epoch 18/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9405, Acc: 0.661
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.0137, Acc: 0.590
# Epoch 18 | train loss 0.9405 acc 0.661 | val loss 1.0137 acc 0.590
# Epoch 19/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9089, Acc: 0.651
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.0152, Acc: 0.562
# Epoch 19 | train loss 0.9089 acc 0.651 | val loss 1.0152 acc 0.562
# Early stopping.
# Training completed. Evaluating on test set...
# Evaluating for one epoch...
# Processing batch 1/6...
# Processing batch 2/6...
# Processing batch 3/6...
# Processing batch 4/6...
# Processing batch 5/6...
# Processing batch 6/6...
# Eval - Loss: 0.9655, Acc: 0.594
# Test loss: 0.9655 | Test acc: 0.594
#
#                      precision    recall  f1-score   support
#
#           abolished       0.85      0.82      0.84        56
#             delayed       0.32      0.35      0.33        20
#              normal       0.79      0.67      0.72        72
#             reduced       0.12      0.36      0.19        11
# reduced_and_delayed       0.18      0.10      0.12        21
#
#            accuracy                           0.59       180
#           macro avg       0.45      0.46      0.44       180
#        weighted avg       0.64      0.59      0.61       180
#  Evaluation done. Test set results:
# {'loss': 0.9654858960045709, 'acc': 0.5944444444444444, 'cm': array([[46,  0,  0,  6,  4],
#        [ 0,  7, 11,  1,  1],
#        [ 1, 15, 48,  6,  2],
#        [ 4,  0,  1,  4,  2],
#        [ 3,  0,  1, 15,  2]])}
#
# ================================================================================
# MODE=erp | MODEL=resnet
# ResNet18 freeze_backbone=True trainable params: 2,565
# Running experiment with mode=erp and model_kind=resnet...
# Number of trainable parameters: 2565
# Starting training...
# Epoch 1/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.5787, Acc: 0.302
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.5239, Acc: 0.257
# Epoch 01 | train loss 1.5787 acc 0.302 | val loss 1.5239 acc 0.257
# Epoch 2/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.3499, Acc: 0.427
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.2437, Acc: 0.451
# Epoch 02 | train loss 1.3499 acc 0.427 | val loss 1.2437 acc 0.451
# Epoch 3/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.1625, Acc: 0.564
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.1184, Acc: 0.479
# Epoch 03 | train loss 1.1625 acc 0.564 | val loss 1.1184 acc 0.479
# Epoch 4/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.1150, Acc: 0.573
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.0455, Acc: 0.556
# Epoch 04 | train loss 1.1150 acc 0.573 | val loss 1.0455 acc 0.556
# Epoch 5/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.0103, Acc: 0.589
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.0281, Acc: 0.562
# Epoch 05 | train loss 1.0103 acc 0.589 | val loss 1.0281 acc 0.562
# Epoch 6/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9419, Acc: 0.648
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.9577, Acc: 0.590
# Epoch 06 | train loss 0.9419 acc 0.648 | val loss 0.9577 acc 0.590
# Epoch 7/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.8933, Acc: 0.684
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.9627, Acc: 0.569
# Epoch 07 | train loss 0.8933 acc 0.684 | val loss 0.9627 acc 0.569
# Epoch 8/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.8465, Acc: 0.700
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8718, Acc: 0.632
# Epoch 08 | train loss 0.8465 acc 0.700 | val loss 0.8718 acc 0.632
# Epoch 9/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.8138, Acc: 0.750
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8424, Acc: 0.625
# Epoch 09 | train loss 0.8138 acc 0.750 | val loss 0.8424 acc 0.625
# Epoch 10/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.7857, Acc: 0.726
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8902, Acc: 0.618
# Epoch 10 | train loss 0.7857 acc 0.726 | val loss 0.8902 acc 0.618
# Epoch 11/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.7735, Acc: 0.760
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8665, Acc: 0.604
# Epoch 11 | train loss 0.7735 acc 0.760 | val loss 0.8665 acc 0.604
# Epoch 12/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.7769, Acc: 0.729
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8283, Acc: 0.632
# Epoch 12 | train loss 0.7769 acc 0.729 | val loss 0.8283 acc 0.632
# Epoch 13/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.7276, Acc: 0.773
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8106, Acc: 0.625
# Epoch 13 | train loss 0.7276 acc 0.773 | val loss 0.8106 acc 0.625
# Epoch 14/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.7221, Acc: 0.743
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.9774, Acc: 0.549
# Epoch 14 | train loss 0.7221 acc 0.743 | val loss 0.9774 acc 0.549
# Epoch 15/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.6973, Acc: 0.790
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8766, Acc: 0.597
# Epoch 15 | train loss 0.6973 acc 0.790 | val loss 0.8766 acc 0.597
# Epoch 16/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.7326, Acc: 0.724
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8542, Acc: 0.604
# Epoch 16 | train loss 0.7326 acc 0.724 | val loss 0.8542 acc 0.604
# Epoch 17/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.6517, Acc: 0.812
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8684, Acc: 0.583
# Epoch 17 | train loss 0.6517 acc 0.812 | val loss 0.8684 acc 0.583
# Epoch 18/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.6258, Acc: 0.800
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8365, Acc: 0.632
# Epoch 18 | train loss 0.6258 acc 0.800 | val loss 0.8365 acc 0.632
# Epoch 19/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.6020, Acc: 0.823
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8049, Acc: 0.618
# Epoch 19 | train loss 0.6020 acc 0.823 | val loss 0.8049 acc 0.618
# Epoch 20/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.6007, Acc: 0.811
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.7812, Acc: 0.639
# Epoch 20 | train loss 0.6007 acc 0.811 | val loss 0.7812 acc 0.639
# Training completed. Evaluating on test set...
# Evaluating for one epoch...
# Processing batch 1/6...
# Processing batch 2/6...
# Processing batch 3/6...
# Processing batch 4/6...
# Processing batch 5/6...
# Processing batch 6/6...
# Eval - Loss: 0.8025, Acc: 0.694
# Test loss: 0.8025 | Test acc: 0.694
#
#                      precision    recall  f1-score   support
#
#           abolished       0.85      0.93      0.89        56
#             delayed       0.25      0.10      0.14        20
#              normal       0.77      0.83      0.80        72
#             reduced       0.23      0.27      0.25        11
# reduced_and_delayed       0.40      0.38      0.39        21
#
#            accuracy                           0.69       180
#           macro avg       0.50      0.50      0.49       180
#        weighted avg       0.66      0.69      0.67       180
#  Evaluation done. Test set results:
# {'loss': 0.8024845388200548, 'acc': 0.6944444444444444, 'cm': array([[52,  0,  0,  1,  3],
#        [ 1,  2, 16,  1,  0],
#        [ 0,  5, 60,  2,  5],
#        [ 3,  1,  0,  3,  4],
#        [ 5,  0,  2,  6,  8]])}
#
# ================================================================================
# MODE=erp | MODEL=simple
# Running experiment with mode=erp and model_kind=simple...
# Number of trainable parameters: 98085
# Starting training...
# Epoch 1/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.6141, Acc: 0.217
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.5957, Acc: 0.326
# Epoch 01 | train loss 1.6141 acc 0.217 | val loss 1.5957 acc 0.326
# Epoch 2/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.6104, Acc: 0.196
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.5975, Acc: 0.326
# Epoch 02 | train loss 1.6104 acc 0.196 | val loss 1.5975 acc 0.326
# Epoch 3/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.6100, Acc: 0.191
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.6160, Acc: 0.160
# Epoch 03 | train loss 1.6100 acc 0.191 | val loss 1.6160 acc 0.160
# Epoch 4/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.6097, Acc: 0.198
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.5997, Acc: 0.312
# Epoch 04 | train loss 1.6097 acc 0.198 | val loss 1.5997 acc 0.312
# Epoch 5/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.6095, Acc: 0.227
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.5991, Acc: 0.312
# Epoch 05 | train loss 1.6095 acc 0.227 | val loss 1.5991 acc 0.312
# Epoch 6/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.6079, Acc: 0.203
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.5932, Acc: 0.312
# Epoch 06 | train loss 1.6079 acc 0.203 | val loss 1.5932 acc 0.312
# Epoch 7/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.6100, Acc: 0.186
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.5934, Acc: 0.326
# Epoch 07 | train loss 1.6100 acc 0.186 | val loss 1.5934 acc 0.326
# Epoch 8/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.6106, Acc: 0.224
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.5981, Acc: 0.326
# Epoch 08 | train loss 1.6106 acc 0.224 | val loss 1.5981 acc 0.326
# Epoch 9/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.6076, Acc: 0.220
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.5957, Acc: 0.326
# Epoch 09 | train loss 1.6076 acc 0.220 | val loss 1.5957 acc 0.326
# Epoch 10/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.6033, Acc: 0.281
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.5870, Acc: 0.104
# Epoch 10 | train loss 1.6033 acc 0.281 | val loss 1.5870 acc 0.104
# Epoch 11/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.5482, Acc: 0.281
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.4610, Acc: 0.389
# Epoch 11 | train loss 1.5482 acc 0.281 | val loss 1.4610 acc 0.389
# Epoch 12/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.3416, Acc: 0.392
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.1256, Acc: 0.660
# Epoch 12 | train loss 1.3416 acc 0.392 | val loss 1.1256 acc 0.660
# Epoch 13/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.1107, Acc: 0.509
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.9306, Acc: 0.667
# Epoch 13 | train loss 1.1107 acc 0.509 | val loss 0.9306 acc 0.667
# Epoch 14/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 1.0746, Acc: 0.502
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8739, Acc: 0.674
# Epoch 14 | train loss 1.0746 acc 0.502 | val loss 0.8739 acc 0.674
# Epoch 15/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9675, Acc: 0.514
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8969, Acc: 0.479
# Epoch 15 | train loss 0.9675 acc 0.514 | val loss 0.8969 acc 0.479
# Epoch 16/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9643, Acc: 0.516
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8728, Acc: 0.431
# Epoch 16 | train loss 0.9643 acc 0.516 | val loss 0.8728 acc 0.431
# Epoch 17/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9140, Acc: 0.516
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8987, Acc: 0.611
# Epoch 17 | train loss 0.9140 acc 0.516 | val loss 0.8987 acc 0.611
# Epoch 18/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9463, Acc: 0.530
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.7850, Acc: 0.667
# Epoch 18 | train loss 0.9463 acc 0.530 | val loss 0.7850 acc 0.667
# Epoch 19/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# ...
# Epoch 02 | train loss 1.1459 acc 0.497 | val loss 0.9678 acc 0.431
# Epoch 3/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9916, Acc: 0.523
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.7679, Acc: 0.715
# Epoch 03 | train loss 0.9916 acc 0.523 | val loss 0.7679 acc 0.715
# Epoch 4/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9230, Acc: 0.517
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.7584, Acc: 0.618
# Epoch 04 | train loss 0.9230 acc 0.517 | val loss 0.7584 acc 0.618
# Epoch 5/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.8846, Acc: 0.517
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8353, Acc: 0.438
# Epoch 05 | train loss 0.8846 acc 0.517 | val loss 0.8353 acc 0.438
# Epoch 6/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.8717, Acc: 0.535
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 1.0284, Acc: 0.500
# Epoch 06 | train loss 0.8717 acc 0.535 | val loss 1.0284 acc 0.500
# Epoch 7/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.8905, Acc: 0.542
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.9248, Acc: 0.431
# Epoch 07 | train loss 0.8905 acc 0.542 | val loss 0.9248 acc 0.431
# Epoch 8/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.8636, Acc: 0.540
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.7499, Acc: 0.694
# Epoch 08 | train loss 0.8636 acc 0.540 | val loss 0.7499 acc 0.694
# Epoch 9/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.8486, Acc: 0.556
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8468, Acc: 0.625
# Epoch 09 | train loss 0.8486 acc 0.556 | val loss 0.8468 acc 0.625
# Epoch 10/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9341, Acc: 0.521
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8935, Acc: 0.472
# Epoch 10 | train loss 0.9341 acc 0.521 | val loss 0.8935 acc 0.472
# Epoch 11/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9277, Acc: 0.538
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.9970, Acc: 0.514
# Epoch 11 | train loss 0.9277 acc 0.538 | val loss 0.9970 acc 0.514
# Epoch 12/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.9227, Acc: 0.521
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8450, Acc: 0.500
# Epoch 12 | train loss 0.9227 acc 0.521 | val loss 0.8450 acc 0.500
# Epoch 13/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.8750, Acc: 0.533
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.7403, Acc: 0.729
# Epoch 13 | train loss 0.8750 acc 0.533 | val loss 0.7403 acc 0.729
# Epoch 14/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.8688, Acc: 0.503
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8120, Acc: 0.465
# Epoch 14 | train loss 0.8688 acc 0.503 | val loss 0.8120 acc 0.465
# Epoch 15/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.8739, Acc: 0.540
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.7423, Acc: 0.708
# Epoch 15 | train loss 0.8739 acc 0.540 | val loss 0.7423 acc 0.708
# Epoch 16/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.8680, Acc: 0.559
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.7717, Acc: 0.493
# Epoch 16 | train loss 0.8680 acc 0.559 | val loss 0.7717 acc 0.493
# Epoch 17/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.8869, Acc: 0.549
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8470, Acc: 0.486
# Epoch 17 | train loss 0.8869 acc 0.549 | val loss 0.8470 acc 0.486
# Epoch 18/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.8440, Acc: 0.569
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.7495, Acc: 0.521
# Epoch 18 | train loss 0.8440 acc 0.569 | val loss 0.7495 acc 0.521
# Epoch 19/20 starting...
# Training for one epoch...
# Processing batch 1/18...
# Processing batch 2/18...
# Processing batch 3/18...
# Processing batch 4/18...
# Processing batch 5/18...
# Processing batch 6/18...
# Processing batch 7/18...
# Processing batch 8/18...
# Processing batch 9/18...
# Processing batch 10/18...
# Processing batch 11/18...
# Processing batch 12/18...
# Processing batch 13/18...
# Processing batch 14/18...
# Processing batch 15/18...
# Processing batch 16/18...
# Processing batch 17/18...
# Processing batch 18/18...
# Train - Loss: 0.8323, Acc: 0.547
# Evaluating for one epoch...
# Processing batch 1/5...
# Processing batch 2/5...
# Processing batch 3/5...
# Processing batch 4/5...
# Processing batch 5/5...
# Eval - Loss: 0.8427, Acc: 0.438
# Epoch 19 | train loss 0.8323 acc 0.547 | val loss 0.8427 acc 0.438
# Early stopping.
# Training completed. Evaluating on test set...
# Evaluating for one epoch...
# Processing batch 1/6...
# Processing batch 2/6...
# Processing batch 3/6...
# Processing batch 4/6...
# Processing batch 5/6...
# Processing batch 6/6...
# Eval - Loss: 0.7867, Acc: 0.689
# Test loss: 0.7867 | Test acc: 0.689
#
#                      precision    recall  f1-score   support
#
#           abolished       0.88      0.93      0.90        56
#             delayed       0.00      0.00      0.00        20
#              normal       0.76      0.89      0.82        72
#             reduced       0.22      0.64      0.33        11
# reduced_and_delayed       0.20      0.05      0.08        21
#
#            accuracy                           0.69       180
#           macro avg       0.41      0.50      0.43       180
#        weighted avg       0.62      0.69      0.64       180
# C:\Users\ortizo\IdeaProjects\ssep_simulation\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ortizo\IdeaProjects\ssep_simulation\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ortizo\IdeaProjects\ssep_simulation\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#  Evaluation done. Test set results:
# {'loss': 0.7867164267434015, 'acc': 0.6888888888888889, 'cm': array([[52,  0,  0,  2,  2],
#        [ 0,  0, 19,  1,  0],
#        [ 0,  0, 64,  7,  1],
#        [ 3,  0,  0,  7,  1],
#        [ 4,  0,  1, 15,  1]])}
#    mode   model  test_acc  test_loss
# 7  both  resnet  0.755556   0.693514
# 5  itpc  simple  0.738889   0.700511
# 2   erp  simple  0.705556   0.744056
# 1   erp  resnet  0.694444   0.802485
# 8  both  simple  0.688889   0.786716
# 6  both  effnet  0.650000   0.865284
# 4  itpc  resnet  0.627778   0.971723
# 0   erp  effnet  0.594444   0.965486
# 3  itpc  effnet  0.561111   0.978949

# %% [markdown]
#  Now we can plot the learning curves.

# %%
def plot_hist(hist, title=""):
    plt.figure()
    plt.plot(hist["epoch"], hist["tr_loss"], label="train_loss")
    plt.plot(hist["epoch"], hist["va_loss"], label="val_loss")
    plt.title(title)
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.legend()
    plt.show()


res_df = pd.DataFrame(results).sort_values("test_acc", ascending=False)
print(res_df)

plot_hist(hists[("erp","simple")], "ERP + Simple CNN")
plot_hist(hists[("itpc","simple")], "ITPC + Simple CNN")
plot_hist(hists[("both","simple")], "Both + Simple CNN")
plot_hist(hists[("erp","resnet")], "ERP + resnet")
plot_hist(hists[("itpc","resnet")], "ITPC + resnet")
plot_hist(hists[("both","resnet")], "Both + resnet")
plot_hist(hists[("erp","effnet")], "ERP + effnet")
plot_hist(hists[("itpc","effnet")], "ITPC + effnet")
plot_hist(hists[("both","effnet")], "Both + effnet")
# Out:
#    mode   model  test_acc  test_loss
# 7  both  resnet  0.755556   0.693514
# 5  itpc  simple  0.738889   0.700511
# 2   erp  simple  0.705556   0.744056
# 1   erp  resnet  0.694444   0.802485
# 8  both  simple  0.688889   0.786716
# 6  both  effnet  0.650000   0.865284
# 4  itpc  resnet  0.627778   0.971723
# 0   erp  effnet  0.594444   0.965486
# 3  itpc  effnet  0.561111   0.978949

# %%
# store test set labels and images in a separate folder for error analysis
import shutil
ERROR_ANALYSIS_DIR = Path("error_analysis")
#set subfolders for erp, itpc, and full images
ERROR_ANALYSIS_DIR.mkdir(exist_ok=True)
(ERP_ERROR_DIR := ERROR_ANALYSIS_DIR / "erp").mkdir(exist_ok=True)
(ITPC_ERROR_DIR := ERROR_ANALYSIS_DIR / "itpc").mkdir(exist_ok=True)
(FULL_ERROR_DIR := ERROR_ANALYSIS_DIR / "full").mkdir(exist_ok=True)

test_df.to_csv(ERROR_ANALYSIS_DIR / "test_metadata.csv", index=False)
# copy test images to error_analysis folder for easy access
for _, row in test_df.iterrows():
    shutil.copy(row["erp_path"], ERP_ERROR_DIR / Path(row["erp_path"]).name)
    shutil.copy(row["itpc_path"], ITPC_ERROR_DIR / Path(row["itpc_path"]).name)
    shutil.copy(row["full_path"], FULL_ERROR_DIR / Path(row["full_path"]).name)
